# %% [markdown]
# <a href="https://colab.research.google.com/github/anshvaishnav2408/ML-AND-PYTHON/blob/main/ml_learning%2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= True
y= False
print('x and y is',x and y)
print('x or y is',x or y)
print('not x is',not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %%
x = 12
y= 4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %%
x = "hello world"
print('h' in x )
print('h' not in x)
# Out:
# True
# False

# %%
import cmath
a=complex(20+5j)
b= complex(5+3j)
print('a+b' , a+b)
print('a-b', a-b)
print('a*b' , a*b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)

# %%
import math
a= int(input('enter the value of a :'))
b= int(input('rnter the value of b :'))
c= int(input('enter the value of c :'))

s =(a+b+c)/2
area = math.sqrt(s*(s-a)*(s-b)*(s-c))
print('the area of the triangle is',area)
# Out:
# enter the value of a :12
# rnter the value of b :12
# enter the value of c :23
# the area of the triangle is 39.420013952306

# %%
a = input("enter the value of a :")
a = a.lower()

if(a=='a' or a=='e' or a=='i' or a=='o' or a=='u'):
  print(" character  the vowel")
else:
    print("character  is a constant")
# Out:
# enter the value of a :b
# character  is a constant

# %%
n = int(input("enter any number"))
[n for i in range(1,11) if]

# %%
a = input("enter the number : ")
while(a!= null):
  if(a)

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_car(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)



c1 = Car("Toyota", "Camry", 2022)
c1.display_car()
# Out:
# Brand: Toyota
# Model: Camry
# Year: 2022

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display(self):
        print("Employee Name:", self.name)
        print("Salary:", self.salary)



emp1 = Employee("Rahul", 50000)
emp1.display()
# Out:
# Employee Name: Rahul
# Salary: 50000
